# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import sympy as sp
from sympy.plotting import plot3d

def paraboloid(a,b,x0,y0): 
  x, y = sp.symbols('x y')
  z=((x**2)/a)+((y**2)/b)
  plan=z.subs([(x,x0),(y,y0)])+sp.diff(z,x).subs([(x,x0)])*(x-x0)+sp.diff(z,y).subs([(y,y0)])*(y-y0)
  plot3d(plan,z)

interactive(paraboloid, a=widgets.IntSlider(value=5, description='a', max=15, min=-15),b=widgets.IntSlider(value=5, description='b', max=15, min=-15),x0=widgets.IntSlider(value=5, description='x0', max=15, min=-15),y0=widgets.IntSlider(value=5, description='y0', max=15, min=-15))
# Out:
# interactive(children=(IntSlider(value=5, description='a', max=15, min=-15), IntSlider(value=5, description='b'…

# %%
from sympy import summation, symbols, cos, sin, pi
from sympy.plotting import plot

def SF(t):
    S=32/3/pi/pi*summation(1 / (i*i)*sin(i*pi/4) * sin(pi*i*x)*cos(i*pi*t), [i, 1, 20])
    return(S)


# I sympy måste vi noga ange det som ska vara symboler
i = symbols('i', integer=True)  # Symboler för heltal
x = symbols('x')  # Behöver lite fler symboler


#print(SF)
  

for j in [0, 0.1, 0.2, 0.3, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1]:
    plot(SF(j),(x,0,1), xlim=(0,1), ylim=(-1,1))

# %%
import PySimpleGUI as sg

sg.theme('DarkAmber')   # Add a touch of color
# All the stuff inside your window.
layout = [  [sg.Text('Some text on Row 1')],
            [sg.Text('Enter something on Row 2'), sg.InputText()],
            [sg.Button('Ok'), sg.Button('Cancel')] ]

# Create the Window
window = sg.Window('Window Title', layout)
# Event Loop to process "events" and get the "values" of the inputs
while True:
    event, values = window.read()
    if event == sg.WIN_CLOSED or event == 'Cancel': # if user closes window or clicks cancel
        break
    print('You entered ', values[0])

window.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import PySimpleGUI as sg
#       3 sg.theme('DarkAmber')   # Add a touch of color
#       4 # All the stuff inside your window.
#
# ModuleNotFoundError: No module named 'PySimpleGUI'
