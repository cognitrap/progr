# %% [markdown]
# ### Begreppet 'array' i linjär algebra
#
# Vi utgår från dina kunskaper om listor i python. Element i en array måste vara av samma typ, till skillnad från listor där elementen kan vara av olika datatyper.
#
# Vi måste nu välja om vi ska använda numpy eller scipy. Vi väljer en kombination. Se tex. https://docs.scipy.org/doc/scipy/reference/tutorial/linalg.html
#
#
# Först gör vi en vektor `v` genom

# %%
import numpy as np

v=np.array([1.,2.,2.,1.,4.2])
print(v)
print(type(v)) #vilken datatyp
# Out:
# [1.  2.  2.  1.  4.2]
# <class 'numpy.ndarray'>

# %% [markdown]
# Vektorer har för addition, subtraktion, division och multiplikation elementvisa operationer.
#
# Det innebär att element på samma plats adderas, subtraheras, divideras eller multipliceras. Vi definierar två vektorer och utför de 4 räknesätten.

# %%
import numpy as np

v1=np.array([1.,0.,-1.,4.])
v2=np.array([3.,1.,1.,-8.])

print(v1+v2)
print(v1-v2)
print(v1/v2)
print(v1*v2)
print(v1+1) #broadcasting En etta adderas till alla element
# Out:
# [ 4.  1.  0. -4.]
# [-2. -1. -2. 12.]
# [ 0.33333333  0.         -1.         -0.5       ]
# [  3.   0.  -1. -32.]
# [2. 1. 0. 5.]

# %% [markdown]
# Lägg märke till skillnaden mot listor. Om L1 och L2 är listor med tal som element så:
#
# - L1+L2 är då konkatenering
# - L1-L2 är inte definierad
# - L1/L2 är inte definierad
# - L1\*L2 är inte definierad

# %%
import numpy as np

L1=[2,3]
L2=[1,1]
print(L1+L2) #kommentera bort de som är fel annars
#ser du inte allas resultat
#print(L1-L2) #fel
#print(L1/L2) #fel
#print(L1*L2) #fel
print(2*L1) #konkatenering
# Out:
# [2, 3, 1, 1]
# [2, 3, 2, 3]

# %% [markdown]
# Däremot kan man ta sinus för en array och en lista och det blir samma resultat för elementen.

# %%
import numpy as np
Lista=[34,56]
Vektor=np.array([34,56])
print("sinus för en Lista", np.sin(Lista))
print("sinus för en Vektor", np.sin(Vektor))
# Out:
# sinus för en Lista [ 0.52908269 -0.521551  ]
# sinus för en Vektor [ 0.52908269 -0.521551  ]

# %% [markdown]
# Några behändiga enkla kommandon

# %%
import numpy as np

a=np.zeros(7)
print("a=", a)
# Out:
# a= [0. 0. 0. 0. 0. 0. 0.]

# %%
a=np.ones(4)
print("a=", a)
# Out:
# a= [1. 1. 1. 1.]

# %%
a=np.arange(2,9,3)
print("a=", a)
# Out:
# a= [2 5 8]

# %% [markdown]
# Naturligtvis kan arrays konkateneras om det behövs.

# %%
a=np.array([1,2,3])
b=np.array([1,0,1])
print(a+b)
c=np.concatenate((a,b))
print(c)
# Out:
# [2 2 4]
# [1 2 3 1 0 1]

# %% [markdown]
# Skilj på vektor, radmatris och kolonnmatris.

# %%
#Vektor
v=np.array([3,3,2,5])

#Radmatris
rm=np.array([[4,1,0,2]])
print(np.shape(rm)) #antalet rader och kolonner

#Kolonnmatris
km=np.array([[5,5,2,1]]).reshape(4,1)
print(np.shape(km))
# Out:
# (1, 4)
# (4, 1)

# %% [markdown]
# Observera att för att skapa kolonnmatrisen går det lika bra att börja med en radmatris

# %%
km=np.array([5,5,2,1]).reshape(4,1)
print(np.shape(km))
# Out:
# (4, 1)

# %% [markdown]
# En matris
#
# $$
# \left(\begin{array}{cccc}
# 1 & 1 &  0\\
# 2 & 1 &  -1\\
# 0 & 1 & 1
# \end{array}\right)
# $$
#
# skrivs som

# %%
M=np.array([[1,1,0],[2,1,-1],[0,1,1]])
print("M=", M)
# Out:
# M= [[ 1  1  0]
#  [ 2  1 -1]
#  [ 0  1  1]]

# %% [markdown]
# ### Intro till linjär algebra användning
#
# Vi tar upp några begrepp från linjär algebra.
#
# Börjar med `dot(M,N)` som är multiplikation mellan matriserna `M` och`N`.
#
# Vi utför
# $$
# M \cdot N=
# \left(\begin{array}{cccc}
# 1 & 1 \\
# 2 & 1 \\
# \end{array}\right)
# \left( \begin{array}{ccc}
# 1 & 1\\
# 0 & -1\\
# \end{array}\right)
# $$

# %%
M=np.array([[1,1],[2,1]])
N=np.array([[1,1],[0,-1]])
D=np.dot(M,N)
print(D)
# Out:
# [[1 0]
#  [2 1]]

# %% [markdown]
# Symbolen `@` kan också användas.

# %%
E=M@N
print(E)
# Out:
# [[1 0]
#  [2 1]]

# %% [markdown]
# Transponatet är en metod

# %%
M=np.array([[1,1],[2,1]])
B=M.T
print("B=",B,"\n\n","M=",M)
# Out:
# B= [[1 2]
#  [1 1]]
#
#  M= [[1 1]
#  [2 1]]

# %% [markdown]
# Likaså är storleken en metod

# %%
M=np.array([[1,1],[2,1],[3,3]])
s=M.shape
print(s)
print(s[0])
# Out:
# (3, 2)
# 3

# %% [markdown]
# Determinanten i numpy erhålls från

# %%
import numpy as np

M=np.array([[1,1],[2,1]])
dtr=np.linalg.det(M)
print(dtr)
# Out:
# -1.0

# %% [markdown]
# Beräkning av invers.

# %%
import numpy as np

M=np.array([[1,1],[2,1]])
print("Matrisen är\n", M)
Minv=np.linalg.inv(M)
print("Inversen är\n", Minv)
C=np.dot(M,Minv)
print("Matrisen gånger inversen är enhetsmatrisen\n",C)
# Out:
# Matrisen är
#  [[1 1]
#  [2 1]]
# Inversen är
#  [[-1.  1.]
#  [ 2. -1.]]
# Matrisen gånger inversen är enhetsmatrisen
#  [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# #### Skalärprodukt
#
# `dot(M,N)` hanterar även vektorer så den kan användas för att beräkna skalärprodukter. Vi beräknar skalärprodukten mellan $(1,3,5)$ och $(2,0,-1)$ som

# %%
import numpy as np
u=np.array([1,3,5])
v=np.array([2,0,-1]).reshape(3,1)
C=np.dot(u,v)
print(C)
# Out:
# [-3]

# %% [markdown]
# Längden av en vektor beräknas med `.norm`

# %%
import numpy as np
u=np.array([1,3,5])
v=np.array([2,0,-1]).reshape(3,1)

print(np.linalg.norm(u))
print(np.linalg.norm(v))
# Out:
# 5.916079783099616
# 2.23606797749979

# %% [markdown]
# Vi kan nu beräkna vinkeln mellan vektorerna ur definitionen av skalärprodukt. Vi använder ett ortonormerat system.
# $$
# \overline{u}\bullet\overline{v}=\left\{ \begin{array}{c}
# \left|\overline{u}\right|\left|\overline{v}\right|\cos\left[\overline{u},\overline{v}\right]\,\,\textrm{om }\overline{u}\neq\overline{0},\textrm{ och }\overline{v}\neq\overline{0}\\
# 0\,\,\textrm{om }\overline{u}=\overline{0}\,\textrm{eller }\overline{v}=\overline{0}
# \end{array}\right.
# $$
#
# som ger oss formeln för vinkeln
#
# $$
# \left[\overline{u},\overline{v}\right]=\cos^{-1}\left(\frac{\overline{u}\bullet\overline{v}}{\left|\overline{u}\right|\left|\overline{v}\right|}\right)
# $$

# %%
import numpy as np
u=np.array([1,3,5])
v=np.array([2,0,-1]).reshape(3,1)

a=np.dot(u,v)/(np.linalg.norm(u)*np.linalg.norm(v))

vinkelrad=np.arccos(a)
vinkeldeg=vinkelrad/np.pi*180.
print('{:.1f}'.format(vinkeldeg[0]))
# Out:
# 103.1

# %% [markdown]
# #### Projektionsformeln
#
# $$
# \overline{u}_{\overline{v}}=\frac{\overline{u}\bullet\overline{v}}{\left|\overline{v}\right|^{2}}\overline{v}.
# $$

# %%
import numpy as np
u=np.array([1,3,5])
v=np.array([2,0,-1]).reshape(3,1)

u_on_v=np.dot(u,v)/(np.linalg.norm(v)*np.linalg.norm(v))*v

print(u_on_v)
# Out:
# [[-1.2]
#  [-0. ]
#  [ 0.6]]

# %% [markdown]
# #### Plan
#
# Vi bestämmer ett plan som är parallellt med de två vektorerna $x=(1,3,5)$, $y=(-1,1,0)$ och går igenom punkten $P: (3,3,4)$
#
# Vektorprodukten benämns $z$. Planet $ax+by+cz+d=0$ har koefficienterna $a=z[0]$, $b=z[1]$ och $c=z[2]$. Vi bestämmer $d=-(ax+by+cz)$ där $x$, $y$ och $z$ är från punkten $P$.

# %%
import numpy as np
P=[3,3,4]
x=np.array([1,3,5])
y=np.array([-1,1,0])
z=np.cross(x,y)
print("a b c", z)
d=-(z[0]*P[0]+z[1]*P[1]+z[2]*P[2])
print("d", d)
# Out:
# a b c [-5 -5  4]
# d 14

# %% [markdown]
# #### Vi löser ett ekvationssystem
#
# Ekvationssystemet
#
# $$
# \left\{ \begin{array}{rcrcrcr}
# 2x_{1} & + & x_{2} & - & x_{3} & = & 2\\
# x_{1} & - & 2x_{2} & + & 3x_{3} & = & 4\\
# 2x_{1} & + & x_{2} & - & 4x_{3} & = & 1
# \end{array}\right.
# $$
#
# Kan skrivas med matriser
# $$
# A=\left(\begin{array}{rrr}
# 2 & 1 & -1\\
# 1 & -2 & 3\\
# 2 & 1 & -4
# \end{array}\right)
# $$
#
# $$
# X=\left(\begin{array}{c}
# x_{1}\\
# x_{2}\\
# x_{3}
# \end{array}\right)
# $$
#
# och
# $$
# b=\left(\begin{array}{c}
# 2\\
# 4\\
# 1
# \end{array}\right)
# $$
#
# explicit som
#
# $$
# \left(\begin{array}{rrr}
# 2 & 1 & -1\\
# 1 & -2 & 3\\
# 2 & 1 & -4
# \end{array}\right)\left(\begin{array}{c}
# x_{1}\\
# x_{2}\\
# x_{3}
# \end{array}\right)=\left(\begin{array}{c}
# 2\\
# 4\\
# 1
# \end{array}\right).
# $$
#
#
# Systemet $ AX=b $ löses formellt som $A^{-1} AX=A^{-1}b$ som är $X=A^{-1}b$.
#
# Vi ska således beräkna inversen och multiplicera med högerledet.

# %%
A=np.array([[2,1,-1],[1,-2,3],[2,1,-4]])
b=np.array([2,4,1]).reshape(3,1)
Ainv=np.linalg.inv(A)
X=Ainv@b
print("Lösningarna är \n", X)
# Out:
# Lösningarna är
#  [[ 1.53333333]
#  [-0.73333333]
#  [ 0.33333333]]

# %% [markdown]
# #### solve()
#
# Python har en färdig rutin för att lösa ekvationssystem.

# %%
A=np.array([[2,1,-1],[1,-2,3],[2,1,-4]])
b=np.array([2,4,1]).reshape(3,1)
x=np.linalg.solve(A,b)
print(x)
# Out:
# [[ 1.53333333]
#  [-0.73333333]
#  [ 0.33333333]]

# %% [markdown]
# #### Blockmatriser (stacking)
#
# Vektorer och matriser kan sättas ihop (staplas).
# De kan läggas ovanpå varandra, 'vertical', eller sidan om varandra, 'horisontal'.

# %%
a = np.array([1, 2, 3])
b = np.array([2, 3, 4])

c=np.vstack((a,b))
d=np.hstack((a,b))

print(c,"\n\n",d)
# Out:
# [[1 2 3]
#  [2 3 4]]
#
#  [1 2 3 2 3 4]

# %%
a = np.array([1, 2, 3]).reshape(3,1)
b = np.array([2, 3, 4]).reshape(3,1)

c=np.vstack((a,b))
d=np.hstack((a,b)) #vektorerna a och b placeras som kolonner
print(c,"\n\n",d)
# Out:
# [[1]
#  [2]
#  [3]
#  [2]
#  [3]
#  [4]]
#
#  [[1 2]
#  [2 3]
#  [3 4]]

# %% [markdown]
# Observera att i föregående motsvarar d att lägga vektorerna i kolonner som vi gör tex. vid skapandet av basbytesmatriser.

# %% [markdown]
# #### Egenvärden och egenvektorer
#
# Kommandot `eig(A)` returnerar egenvärdena, i detta fall 3 stycken. Därefter följer egenvektorerna i en matris. Första kolonnen är egenvektorn till det först angivna egenvärdet osv.

# %%
import numpy as np
A=np.array([[1,2,2],[2,7,1],[2,1,7]])

EV=np.linalg.eig(A)
print(EV)
# Out:
# (array([-8.8817842e-16,  9.0000000e+00,  6.0000000e+00]), array([[-9.42809042e-01,  3.33333333e-01, -1.35054202e-16],
#        [ 2.35702260e-01,  6.66666667e-01, -7.07106781e-01],
#        [ 2.35702260e-01,  6.66666667e-01,  7.07106781e-01]]))

# %%
import numpy as np
A=np.array([[1,2,2],[2,7,1],[2,1,7]])

EV=np.linalg.eig(A)

print("lambda1={:.1f}".format(EV[0][0]))
print("lambda2={:.1f}".format(EV[0][1]))
print("lambda3={:.1f}".format(EV[0][2]))

EVT=EV[1].T
#print(EVT)
EVT=np.around(EVT,1)
print("egenvektor 1", EVT[0])
print("egenvektor 2", EVT[1])
print("egenvektor 3", EVT[2])
# Out:
# lambda1=-0.0
# lambda2=9.0
# lambda3=6.0
# egenvektor 1 [-0.9  0.2  0.2]
# egenvektor 2 [0.3 0.7 0.7]
# egenvektor 3 [-0.  -0.7  0.7]

# %% [markdown]
# ####

# %%
# Out:
# 10
