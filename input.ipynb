# %% [markdown]
# # Input till program
#
# Vi har hitintills bara låtit programmen skriva ut resultat. Indata har funnits inuti i programmet. Det är inte så flexibelt. Vi tittar nu på hur program kan ta emot data från tex. tangentbordet.
#
# Huvudkommandot är `input()`. (vi såg det lite i introduktionen)
#
# Ofta har man behov av att samtidigt ange vad det är som ska in, det görs med en sträng i början. När rutan för inmatning kommer upp skriver du in talet där och trycker på retur.

# %%
a=input("ange ett heltal")
# Out:
# ange ett heltal5

# %% [markdown]
# Variabeln `a` tilldelas det värde du anger.

# %% [markdown]
# Vi kontrollerar genom en print-sats

# %%
a=input("ange ett heltal")
print(a)
# Out:
# ange ett heltal4
# 4

# %% [markdown]
# Vi försöker göra något med talet.

# %%
a=input("ange ett heltal")
print(a+a)
# Out:
# ange ett heltal3
# 33

# %% [markdown]
# Oj! Talet(?) är inte ett heltal, utan det är en sträng.
#
# Detta är mycket av säkerhetsskäl. Din uppgift nu som programmerare är att undersöka vad det är du fått in och hantera det på ett säkert sätt. Programmet ska inte krascha för att någon matar in talet 0 tex. eller bara allmänt nonsens.
#
# I vårt fall räcker det med att vi gör om det till ett heltal, om det är det vi behöver i programmet...

# %%
a=input("ange ett heltal")
a=int(a)
print(a+a)
# Out:
# ange ett heltal3
# 6

# %% [markdown]
# Detta är en så vanlig sak så det skrivs ofta på en rad

# %%
a=int(input("ange ett heltal"))

# %% [markdown]
# Observera att detta är en sammansatt funktion precis som i matematiken `int(input())=f(g(x))`

# %% [markdown]
# Om du vill ha flyttal så ska det stå `float()`. Skriver du int när det ska vara float så får man felmeddelande.

# %%
d=int(input("Ange ett tal med 3 decimaler"))
print(d)
# Out:
# Ange ett tal med 3 decimaler 3.141
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-0e4265ac587b> in <module>
# ----> 1 d=int(input("Ange ett tal med 3 decimaler"))
#       2 print(d)
#
# ValueError: invalid literal for int() with base 10: '3.141'

# %% [markdown]
# ## Enkel styrning av output
#
# Fastän detta ska handla om input tar vi några enkla o bra saker för utskriften.
# Kommandon för ny rad och tabulatorsteg ges av `\n` respektive `\t`.
# Bakstrecket kallas för ett 'escape'-tecken. Detta måste in före n och t, annars är de naturligtvis vanliga bokstäver i strängen.

# %%
print("Solen går strax upp\nDagen är här")
# Out:
# Solen går strax upp
# Dagen är här

# %%
print("Den hemliga koden är\t345197")
# Out:
# Den hemliga koden är	345197
