# %% [markdown]
# # Mer om listor
#
# ## range()
#
#
# Först ett begrepp som skapar list-liknande ting och som ofta används i samband med listor. range() är en så kallad inbyggd funktion (färdig funktion).
#
# Kommandot har följande struktur: `range(start, stop, step)`
# Men ofta används inte alla 3 parametrarna. Parametrarna start och step behöver inte anges men stop måste alltid anges. Skriver man `range(8)` så tolkas det automatiskt som  stop är 8 att intervallet är från 0 till 7 eftersom det är exklusivt stop, precis som vid listor. Parametrerna måste vara heltal. För float finns ett annat kommando
#
# Kommandot range används ofta då man bara vill ha en enkel upprepning:

# %%
for i in range(7):
    print(i,i*3)

# %% [markdown]
# Smidigare än att arbeta med en lista.
#
# Låt oss prova lite varianter. Och undersöka vad det är för typ av objekt egentligen.
#
# `range(0,8)` är samma sak som `range(8)`
#
# Vi undersöker och skriver in steg

# %%
for i in range(0,7,2):
    print(i,i*3)
# Out:
# 0 0
# 2 6
# 4 12
# 6 18

# %%
for i in range(0,7,8): #steg större än intervallet
    print(i,i*3)

# %% [markdown]
# Bara att experimentera vidare.

# %% [markdown]
# Kommandot `range()` är inte en lista, man kan inte skriva

# %%
print(range(3))

# %% [markdown]
# och få ut en lista.

# %% [markdown]
# Man behöver inte stega framåt, det går bra att stega bakåt.

# %%
for i in range(0,-5,-1):
    print(i)

# %% [markdown]
# ## Listor 2
#
# Vi skapar en lista med hjälp av `range()`

# %%
L=list(range(8))
print(L)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Vi behöver kommandot `list()` som gör om `range()` till en lista.

# %% [markdown]
# Föregående exempel innehåller en omvandling av en inbyggd funktion till en lista. Detta går att göra med fler datatyper. En populär är

# %%
a="6" #som är en sträng
a=int(a) #omvandlar sträng till datatypen heltal
print(3*a) #nu kan vi räkna med den

# %% [markdown]
# Den klarar även knepigare saker som att tolka decimalpunkt

# %%
a="6.2" #som är en sträng
a=float(a) #omvandlar sträng till datatypen flyttal
print(3*a) #nu kan vi räkna med den

# %% [markdown]
# Man börjar undra... Vad händer om vi gör

# %%
a=True; b=False
a=int(a); b=int(b) 
print(a,b)
# Out:
# 1 0

# %% [markdown]
# Strängar kan plockas i delar till en lista

# %%
a="Det var länge se'n"
b=list(a)
print(b)
# Out:
# ['D', 'e', 't', ' ', 'v', 'a', 'r', ' ', 'l', 'ä', 'n', 'g', 'e', ' ', 's', 'e', "'", 'n']

# %% [markdown]
# Eller om man vill ta bort något felstavat

# %%
a="Konkatanering" #Vår felstavade sträng
a=list(a) #Vi gör om den till en lista
a[6]="e" #Vi rättar
a="".join(a) #Sätter ihop till sträng igen
print(a)
# Out:
# Konkatenering

# %% [markdown]
# Kommandot `"".join` lägger ihop elementen i listan och placerar inget mellan elementen. Det som är mellan citattecknen placeras mellan elementen men vi har inget mellan dem. Testa gärna med att skriva in något annat mellan citattecknen tex. `"?".join(a)`

# %% [markdown]
# Vi skivar upp listor på lite olika sätt för att vänja oss vid tänkandet.
# Först skriver vi ner ett tankestöd i form av en tabell.
#
#
#
#
# | 0 | 1 | 2 | 3 | 4 | 5 | ... | -5 | -4 | -3 | -2 | -1 |
# |----|----|----|----|----|----|----|----|----|----|----|----|
#
#
# där 0 är första elementet i listan och -1 är sista elementet i listan.
#
# Om listan innehåller 5 element har vi
#
# | 0  | 1  | 2  | 3  | 4  |
# |----|----|----|----|----|
# | -5 | -4 | -3 | -2 | -1 |
#
# Och om vi väljer listan `L=[3,7,4,1,8]` så har vi
#
# | 3 | 7 | 4 | 1 | 8 |
# |----|----|----|----|----|
# | 0  | 1  | 2  | 3  | 4  |
# | -5 | -4 | -3 | -2 | -1 |

# %%
L=[3,7,4,1,8]
L[2:4] # 2 inkl till 4 exkl

# %%
L=[3,7,4,1,8]
L[2:5] # 5 är utanför sista index som är 4
# Out:
# [4, 1, 8]

# %%
L[-2]

# %%
L[:-2] #Startar i 0 inkl går till -2 exkl

# %%
L[-2:] #Startar i -2 går till slutet

# %% [markdown]
# Listkommandon anger inte alltid om du ger kommandon utanför indexets gränser.
# I vårt exempel har vi icke-negativa index från 0 tom. 4. Men man kan ange index 5 för att få med det sista elementet. Vad händer om man skriver

# %%
L[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-7d1d7a0424fb> in <module>
# ----> 1 L[5]
#
# IndexError: list index out of range

# %% [markdown]
# Lägg märke till skillnaden. `L[2:5]` ger inte felmeddelande men `L[5]` ger felmeddelande!
#
# Så om vi kanske tänkt helt fel och skriver

# %%
L[0:3000]
# Out:
# [3, 7, 4, 1, 8]

# %% [markdown]
# Så får vi inget felmeddelande.
#
# Vad händer om båda gränserna anges fel (utanför listans index)?

# %%
L[10:100]

# %% [markdown]
# Jo, vi får en tom lista, ok.

# %% [markdown]
# ## Ta bort och lägga till element
#
# Vi börjar med en lista och tar bort ett element.

# %%
L=[3,4,5]
print(L)
L[1:2]=[] #dvs element med index 1, som är talet 4
print(L)
# Out:
# [3, 4, 5]
# [3, 5]

# %% [markdown]
# Vi lägger till en lista sist

# %%
L=[3,4,5]
L[3:]=[1,1,0]
print(L)
# Out:
# [3, 4, 5, 1, 1, 0]

# %% [markdown]
# Lägga till först

# %%
L=[3,4,5]
L[:0]=["a","b","c"]
print(L)
# Out:
# ['a', 'b', 'c', 3, 4, 5]

# %% [markdown]
# Man börjar undra?
# Kan man stoppa in en bit lista i listan?

# %%
L=[3,4,5]
L[1:2]=["a","b","c"]
print(L)
# Out:
# [3, 'a', 'b', 'c', 5]

# %% [markdown]
# Tydligen ersatte vi talet 4 med vår lista över strängar. Kanske kan vi få in vår bit utan att ta bort något? Vi försöker med

# %%
L=[3,4,5]
L[1:1]=["a","b","c"]
print(L)
# Out:
# [3, 'a', 'b', 'c', 4, 5]

# %% [markdown]
# Ok :-)

# %% [markdown]
# Man kan kontrollera om ett visst tal finns i en lista med hjälp av `in` och `not in`.

# %%
3 in L

# %%
0 in L

# %% [markdown]
# ## Metoder på listor
#
# Vi introducerar metoder i python. De har formen `name.action`.
# Vi ser på några exempel.

# %%
L=[2,3,5]
L.append(2) #en metod
print(L)

# %% [markdown]
# Fungerade utmärkt. Kanske kan man få för sig att följande skulle fungera, det känns lite logiskt.

# %%
L=[2,3,5]
Lny=L.append(2)
print(Lny)

# %% [markdown]
# Men som du ser så händer inget. Det finns ingen lista med namnet Lny fastän vi gjort en tilldelning. Denna typ av operationer kallas för 'in place' därför att den direkt gör något med objektet.
#
# Däremot fungerar, naturligtvis

# %%
L=[2,3,2,4,2]
L_nr2=L.count(2) #räknar antalet 2:or i listan
L_nr2

# %% [markdown]
# Ta bort en 2:a (det blir den första)

# %%
L=[2,3,2,4,2]
L.remove(2)
L

# %% [markdown]
# Ändra listans ordning.

# %%
L=[1,2,37]
L.reverse()
L

# %% [markdown]
# ## Mängdbyggare
#
# Inom matematiken finns något som kallas mängdbyggare.
#
# $\{x|x\in\mathbb{R}\}$ som är mängden av alla reella tal (läses: mängden av $x$ sådana att , $x$ tillhör mängden $\mathbb{R}$ ) ($|$ betyder sådana att)
#
# $\{n^{2}|n\in\mathbb{N}\}$ som är mängden av kvadraten på alla naturliga tal
#
# Eller för diskreta ändliga mängder
#
# $M=\{1,2,3,4\}$
#
# $L=\{n^{2}|n\in M\}$ som är mängden $\{1, 4, 9, 16\}$

# %%
M=[1,2,3,4]
L=[n**2 for n in M]
print(L)

# %% [markdown]
# Snabbt och bekvämt för att skapa listor. Fenomenet kallas för listförståelse, 'list comprehension'.

# %% [markdown]
# Vi skriver ett kort program.

# %%
L=list(range(1,100,2)) #endast udda tal
Lkub=[x**3 for x in L] #list comprehension
print("Kuben på udda tal", Lkub)

# %% [markdown]
# ## Slumplistor
#
# Vi genererar listor med slumpmässigt valda naturliga tal.
# Det centrala kommandot är `random`.
# Vi använder _metoden_ sample.

# %%
import random

L=random.sample(range(0,10),8)
print(L)
# Out:
# [5, 8, 4, 2, 6, 1, 0, 3]

# %% [markdown]
# Vi får tal i intervallet 0 (inkl) till 10 (exkl). Vi får 8 tal. I detta kommando kan antalet genererade slumptal inte överstiga antalet tal i intervallet. Vi kan maximalt få 10 slumpade tal, alla olika. Slump utan återläggning.
# Några fler exempel.

# %%
L=random.sample(range(0,10),10)
print(L)
# Out:
# [3, 8, 6, 7, 1, 4, 5, 9, 2, 0]

# %%
L=random.sample(range(0,10),11) #fungerar ej
print(L)

# %% [markdown]
# ## Listor i listor
#
# Man kan ha listor som element i listor.

# %%
L=[2,3, [4,5,['a','b']]]

# %% [markdown]
# Listan L har en lista i sig och i den listan finns ytterligare en lista. Hur adresserar man ett element? Och hur många element har listan egentligen? Vi testar.

# %%
L=[2,3, [4,5,['a','b']]]
len(L)
# Out:
# 3

# %% [markdown]
# Om vi vill ha tag i strängen `'a'` så anger vi först att det är elementet med index 2, däri är det element 2 och däri element 0.

# %%
L=[2,3, [4,5,['a','b']]]
L[2][2][0]
# Out:
# 'a'

# %% [markdown]
# För att få den första inre listan

# %%
L[2]
# Out:
# [4, 5, ['a', 'b']]

# %% [markdown]
# Och hela den inre listan

# %%
L[2][2]
# Out:
# ['a', 'b']

# %% [markdown]
# Från 5

# %%
L[2][1:]
# Out:
# [5, ['a', 'b']]

# %% [markdown]
# Ytterligare ett exempel

# %%
K=[2,3, [4,5,['a','b', 3,4,5,7]]]
K[2][2][1:4]

# %% [markdown]
# Och ett till

# %%
a=[1,2,3]
b=[4,5,6]
c=[7,8,9]
L=[a,b,c]
print(L)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ## Uppgifter
#
# **Uppgift 1**
#
# Väv ihop 2 lika långa listor så  att elementen tas omväxlande, varannan, från de 2 listorna.
# Konstruera listorna slumpmässigt med tal från 1 till 10 och 10 element i varje lista.
#
# [Lösningsförslag](./uppg/Listor2Uppgift1.ipynb)
#
# **Uppgift 2**
#
# Ändra ordningen på elementen i en lista. Säg att vi har en lista L, ändra om så att första elementet i listan hamnar sist i listan M, andra elementet i L hamnar näst sist i M osv.
# Det finns ett kommando för detta L.reverse() men det ska du naturligtvis inte använda.
#
# [Lösningsförslag](./uppg/Listor2Uppgift2.ipynb)
#
#
# **Uppgift 3**
#
# Hur många tal ligger parvis i rätt ordning? Att tal ligger i rätt ordning parvis innebär att det med högre index är större än det med lägre index. I listan [7,11] ligger de i rätt ordning även om de inte direkt följer på varandra som 7 och 8 tex.
# Gå igenom en lista och testa talen parvis; först tal med index 0 och 1, sedan 1 och 2, sedan 2 och 3 osv.
# Anteckna antalet gånger talen ligger parvis rätt.
# Listan skapas slumpmässigt.
#
# [Lösningsförslag](./uppg/Listor2Uppgift3.ipynb)
#
#
# **Uppgift 4**
#
# Leta upp det största talet i en lista.
# I python finns ett kommando för just den uppgiften. Om L är en lista letar max(L) upp det största talet i listan L. Men nu ska du själv leta upp den genom att jämföra talen i listan med varandra. Slumpa listan och leta sedan upp det största talet i listan (utan att använda max). Listan ska innehålla 10 tal valda i intervallet 1-100.
#
# [Lösningsförslag](./uppg/Listor2Uppgift4.ipynb)

# %% [markdown]
# **Uppgift 5**
#
# Generera långa listor och beräkna sannolikheten för att få tal omedelbart efter varandra som är lika.
# Listan L=[1,1,3,5,3,6,6,8,12,14,1,32,1,5,8,9,9,9] innehåller 4 händelser med 2 lika tal: (1,1), (6,6), (9,9) de 2 första och (9,9) de 2 sista.
#
# Vi håller oss till tal i range(10) Svara med tabell. Slumptal skapas genom `s=random.randrange(0,10)` som ger ett tal from. 0 tom. 9. Man behöver inte göra listor men föreslår ändå att du börjar med att generera listor och använder dem (du ska öva på listor i detta avsnitt). Undersök listor med 100000 element och beräkna sannolikheten för längden 2 på sviter. Om du läst sannolikhetslära, beräkna det även teoretiskt.
#
# [Lösningsförslag](./uppg/Listor2Uppgift5.ipynb)
