# %% [markdown]
# ### Uppgift 2

# %%
print("Programmet beräknar a**b för 2 heltal")
a=int(input("Ange a "))
b=int(input("Ange b "))

print("a**b är ", a**b)
# Out:
# Programmet beräknar a**b för 2 heltal
# Ange a 5
# Ange b 55
# a**b är  277555756156289135105907917022705078125
