# %% [markdown]
# Uppgift 2

# %%
"""
Programmet beräknar absolutbeloppet av skillnaden mellan två tal
"""

x=float(input("Ange x "))
y=float(input("Ange y "))

if x>y:
    d=x-y
else:
    d=y-x

print("beloppet av skillnaden är ", d)
# Out:
# Ange x 0
# Ange y 0
# beloppet av skillnaden är  0.0
