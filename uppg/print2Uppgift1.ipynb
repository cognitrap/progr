# %% [markdown]
# **Uppgift 1**

# %%
print("En andragradsekvation kan anges på formen ax^2+bx+c=0")
a=int(input("Ange koefficienten framför andragradstermen"))
b=int(input("Ange koefficienten framför förstagradstermen"))
c=int(input("Ange koefficienten framför konstant-termen"))

print("Andragradsekvationen är {}x^2+{}x+{}=0".format(a,b,c))
# Out:
# En andragradsekvation kan anges på formen ax^2+bx+c=0
# Ange koefficienten framför andragradstermen 2
# Ange koefficienten framför förstagradstermen 2
# Ange koefficienten framför konstant-termen 2
# Andragradsekvationen är 2x^2+2x+2=0
