# %% [markdown]
# ### Lösningsexempel Uppgift1

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.linspace(0, 2*np.pi, 50)
y=np.sin(x)
plt.plot(x,y)

y=np.cos(x)

plt.axis([0,2*np.pi,-1.1,1.1])

plt.plot(x,y)

#Ritas i samma graf!

plt.show()
