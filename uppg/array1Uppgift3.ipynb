# %% [markdown]
# Uppgift 3

# %%
import numpy as np

F=np.array([[5,-3],[-4,9]])

EV=np.linalg.eig(F)

print("Egenvärdena är ", EV[0])

S=EV[1]
ST=EV[1].T
ST=np.around(ST,1)
print("egenvektor 1", ST[0])
print("egenvektor 2", ST[1])

#konstruera matrisen D
D=np.linalg.inv(S)@F@S
D=np.around(D,1)

print("D= ",D)
# Out:
# Egenvärdena är  [ 3. 11.]
# egenvektor 1 [-0.8 -0.6]
# egenvektor 2 [ 0.4 -0.9]
# D=  [[ 3.  0.]
#  [ 0. 11.]]
