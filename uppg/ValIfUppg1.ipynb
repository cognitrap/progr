# %% [markdown]
# Uppgift 1

# %%
import math as m

a=float(input("Ange ett tal som jag ska beräkna tionde-roten ur "))

if a>0:
    b=a**(0.1)
    print("Tionde-roten ur ",a, "är", b)
else:
    print("Talet måste vara större än 0")
# Out:
# Ange ett tal som jag ska beräkna tionde-roten ur -2
# Talet måste vara större än 0
