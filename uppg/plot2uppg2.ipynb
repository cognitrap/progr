# %% [markdown]
# **Uppgift 2**

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.linspace(-10, 10, 50)
y1=(x-3)**2
y2=(x-5)**2
y3=(x+5)**2

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

plt.axis([-10,10,-1.1,20])


plt.show()
