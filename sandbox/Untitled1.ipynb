# %%
# Mall för enkel plottning

import matplotlib.pyplot as plt
import numpy as np

# Värdetabell
x = np.linspace(-2*np.pi, 2*np.pi, 100)
y1 = 0.5*x**2+0.5*x*np.sqrt(x**2+1)+0.5*np.log(x+np.sqrt(x**2+1))+7
A=x+np.sqrt(x**2+1)
y=y1/A

#Nu ritar vi!
plt.plot(x,y)

y3=0.5*x+0.5*(np.sqrt(1+x**2)-x)*(np.log(x+np.sqrt(1+x**2))+14)
plt.plot(x,y3+5)



plt.show()
