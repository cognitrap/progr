# %%
##Lek

from sympy import summation, symbols, cos, sin, pi
from sympy.plotting import plot


# I sympy måste vi noga ange det som ska vara symboler
i = symbols('i', integer=True)  # Symboler för heltal
x = symbols('x')  # Behöver lite fler symboler


# Här följer den summa av fouriertermer jag vill beräkna, se ovan. Satt summan från 1 till 6.
SF=1/12+1/4-summation(1 / (2*pi*i) * sin(2*pi*i*x) + 1/(2*pi*pi*i*i)*cos(2*pi*i*x), [i, 1, 20])

#SF=1/2+summation(1 / (pi*i) * sin(2*pi*i*x), [i, 1, 20])

#SF=-1/12+1/2*x-summation(1/(2*pi*pi*i*i)*cos(2*pi*i*x), [i, 1, 20])


print(SF)
graf=x-x*x/2

plot(SF,graf, (x,-1,1))
# Out:
# -(sin(2*pi*x) + sin(4*pi*x)/2 + sin(6*pi*x)/3 + sin(8*pi*x)/4 + sin(10*pi*x)/5 + sin(12*pi*x)/6 + sin(14*pi*x)/7 + sin(16*pi*x)/8 + sin(18*pi*x)/9 + sin(20*pi*x)/10 + sin(22*pi*x)/11 + sin(24*pi*x)/12 + sin(26*pi*x)/13 + sin(28*pi*x)/14 + sin(30*pi*x)/15 + sin(32*pi*x)/16 + sin(34*pi*x)/17 + sin(36*pi*x)/18 + sin(38*pi*x)/19 + sin(40*pi*x)/20)/(2*pi) - (cos(2*pi*x) + cos(4*pi*x)/4 + cos(6*pi*x)/9 + cos(8*pi*x)/16 + cos(10*pi*x)/25 + cos(12*pi*x)/36 + cos(14*pi*x)/49 + cos(16*pi*x)/64 + cos(18*pi*x)/81 + cos(20*pi*x)/100 + cos(22*pi*x)/121 + cos(24*pi*x)/144 + cos(26*pi*x)/169 + cos(28*pi*x)/196 + cos(30*pi*x)/225 + cos(32*pi*x)/256 + cos(34*pi*x)/289 + cos(36*pi*x)/324 + cos(38*pi*x)/361 + cos(40*pi*x)/400)/(2*pi**2) + 0.333333333333333
